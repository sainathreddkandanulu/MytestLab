# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import SGDRegressor, SGDClassifier
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score,classification_report,roc_auc_score, roc_curve
#from sklearn.datasets import load_boston
#from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree

import matplotlib.pyplot as plt
import tensorflow as tf

# %%
df = pd.read_csv('C:\\Users\\kandanulus\\MyTestlab\\Social_network_Ads.csv')

# %%
tf.random.set_seed(5)

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
X=df.iloc[:,[2,3]].values
y=df.iloc[:,[4]].values

# %%
from sklearn.preprocessing import StandardScaler
stdscl = StandardScaler()
X_scaled = stdscl.fit_transform(X)
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
y_label = minmax.fit_transform(y)

# %%
# split the data in train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y_label, test_size = 0.8, random_state = 123)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80, 2)
# (320, 2)
# (80, 1)
# (320, 1)

# %% [markdown]
# #Architecture of NN

# %%
model = tf.keras.models.Sequential()

#input layer + HL-1
model.add(tf.keras.layers.Dense(units=5, activation = 'relu', input_shape=(2,)))

#HL-2...

model.add(tf.keras.layers.Dense(units=10, activation = 'relu'))


#HL-2...

model.add(tf.keras.layers.Dense(units=6, activation = 'relu'))

          
#Output Layer..

model.add(tf.keras.layers.Dense(units=1, activation = 'sigmoid'))

# %% [markdown]
# #compile the model

# %%
model.compile(optimizer='sgd',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# %%
#Class weights

class_weightage = {0:1,1:2}

# %%
mdl_history = model.fit (X_train, y_train, 
                         epochs=200, 
                         validation_data=(X_test,y_test), class_weight = class_weightage)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.8655 - accuracy: 0.4500 - val_loss: 0.6925 - val_accuracy: 0.3531
# Epoch 2/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8621 - accuracy: 0.3875 - val_loss: 0.6905 - val_accuracy: 0.3531
# Epoch 3/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8588 - accuracy: 0.4125 - val_loss: 0.6874 - val_accuracy: 0.4094
# Epoch 4/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8559 - accuracy: 0.4500 - val_loss: 0.6849 - val_accuracy: 0.4219
# Epoch 5/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8526 - accuracy: 0.4625 - val_loss: 0.6833 - val_accuracy: 0.4250
# Epoch 6/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8492 - accuracy: 0.4500 - val_loss: 0.6818 - val_accuracy: 0.4250
# Epoch 7/200
# ...

# %% [markdown]
# #Model evaluation

# %%
pred_test =
# Out:
#   File "C:\Users\kandanulus\AppData\Local\Temp\ipykernel_30144\1353725818.py", line 1
#     pred_test =
#                 ^
# SyntaxError: invalid syntax

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print('Confusion Matrix for test data')
print(confusion_matrix(y_test, pred_test')
# Out:
#   File "C:\Users\kandanulus\AppData\Local\Temp\ipykernel_30144\1384576546.py", line 2
#     print(confusion_matrix(y_test, pred_test')
#                                               ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# #Grid search

# %%
def build_classsifier(optimizer):
    model = tf.keras.models.Sequential()
    
    #i/p + HL-1
    model.add(tf.keras.layers.Dense(units = 5, activation = 'relu', input_shape = (2,)))
    
    # Hl-2
    model.add(tf.keras.layers.Dense(units = 10, activation = 'relu'))
    
        
    # Hl-3
    model.add(tf.keras.layers.Dense(units = 5, activation = 'relu'))
    
        
    # output layer
    model.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))
    
    model.compile(optimizer=optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    return(model)

# %%
classifier = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn= build_classsifier)

param_grid = {'epochs': [100, 200, 300],
              'optimizer' : [tf.keras.optimizers.Adam(), tf.keras.optimizers.RMSprop(), tf.keras.optimizers.Adagrad()],
              'batch_size' : [20, 40]
}
# Out:
# C:\Users\kandanulus\AppData\Local\Temp\ipykernel_30144\1234506665.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn= build_classsifier)

# %%
grid_search = GridSearchCV(estimator=classifier, 
                          param_grid=param_grid,
                          scoring='accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30144\1768248860.py in <module>
# ----> 1 grid_search = GridSearchCV(estimator=classifier,
#       2                           param_grid=param_grid,
#       3                           scoring='accuracy')
#
# NameError: name 'classifier' is not defined

# %%
grid_search.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30144\20025057.py in <module>
# ----> 1 grid_search.fit(X_train, y_train)
#
# NameError: name 'grid_search' is not defined
